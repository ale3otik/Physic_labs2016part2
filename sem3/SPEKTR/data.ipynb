# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# neon = [[3,2396,6402,'Красная'] , [15,2290,6143,'Красно-Оранж'],
#         [20,1998,5945,'Оранжевая'],[22,2150,5853,'Желтая'], [23,1880,5330,'Зеленая']]

# neon_k = [2630,2612,2546,2538,2514,2496,2482,2436,2424,2348,2322,2242,2188,1926]
# Неон
# [номер в таблице, мера на барабане, Обозначение-цвет]
neon_x = [2841,2830,2804,2780,2772,2735,2726,2708,2698,2682,2662,2640,2630,2610,2600,2582, 2556,2541,2512,2498,2240,2200,2193]
neon_y = [6717,6678,6599,6533,6507,6402,6383,6334,6305,6267,6217,6164,6143,6096,6074,6030,5976,5945,5882,5852,5401,5341,5331]
plt.figure(figsize = (15,7))
plt.title('Neon',size=18)
plt.xlabel('angle marks',size=14)
plt.ylabel('wave length, A',size=14)
plt.grid(True)
plt.plot(neon_x,neon_y,'-o',color='black')
plt.savefig('g1_neon.png')

# %%
#Ртуть
# [номер в таблице, мера на барабане, Обозначение-цвет]

rtut = [[-1,2571,690.7,'K1'], [0, 2328, 623.4, 'K2'], [1,2122,579.1,'1'], [2,2106,577,'2'],
        [3, 1924,546.1,'3'], [4,1498,491.6,'4'], [5,826,435.8,'5'], [6,272,404.7,'6']]

plt.figure(figsize = (15,7))
plt.title('Hg',size=18)
plt.xlabel('angle marks',size=14)
plt.ylabel('wave length, A',size=14)
plt.grid(True)
OX = [x[1] for x in rtut]
OY = [x[2] for x in rtut]
plt.plot(OX,OY,'-o',color='black')
plt.savefig('g1_rtut.png')

# %%
#Водород

vodorod = [[1,2452,'Красный'], [2,1444,'Голубой'], [3,802,'Фиолетовый']]

# %%
#йод
# измерим размер 10 полос
hm0 = 2150
hm10 = 1986
print(t0 - t10)
# Out:
# 164

# %%
hmu_10 = 2964
hmu_15 = 2180
hmu_gr = 1892
