# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
level = [763,713,647,595,520,472,418,362,324,309,265]
angle = np.arange(0,110,10)

plt.figure(figsize=(12,7))
plt.grid(True)
plt.plot(angle,level,'-o')
plt.xlabel("ANGLE")
plt.ylabel("ENERGYA")
